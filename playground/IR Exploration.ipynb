# %%
import pandas as pd

# %%
df = pd.read_csv('../data/train_scaled_with_ir.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0      bloc  icustayid  gender       age  elixhauser  \
# 0           0  0.000000       12.0     1.0  0.203388    0.000000
# 1           1  0.222560       12.0     1.0  0.203388    0.000000
# 2           2  0.356608       12.0     1.0  0.203388    0.000000
# 3           3  0.452837       12.0     1.0  0.203388    0.000000
# 4           4  0.000000       14.0     0.0  0.909010    0.142857
# 5           5  0.222560       14.0     0.0  0.909010    0.142857
# 6           6  0.356608       14.0     0.0  0.909010    0.142857
# 7           7  0.452837       14.0     0.0  0.909010    0.142857
# 8           8  0.527957       14.0     0.0  0.909010    0.142857
# 9           9  0.589582       14.0     0.0  0.909010    0.142857
#
#    re_admission      SOFA  SIRS  Weight_kg         ...           \
# 0           0.0  0.304348  0.25   0.183842         ...
# 1           0.0  0.130435  0.50   0.183842         ...
# 2           0.0  0.086957  0.50   0.183842         ...
# ...

# %% [markdown]
# ### Notes:
#
# * intermediate_reward is negative log rewards. lower IR means higher mortality.
# * Hypothesis: we can eliminate discrete states for both the patient representation and actions
#      * The Kernel and DQN do not need discrete states
#
# ### Todo items:
#
# * Task 1: validate IR using confusion matrix rather than accuracy
# * Task 2: Make Kernelized forward simulation incorporate continuous states and actions, plus physician actions
#
# * Question 1: how to get rid of discrete states for forward simulation?
# * Question 2: how to get rid of discrete actions? How about distribution of actions?
#
# -> Try LSTM or GRU to build simulation of forward actions (seq2seq)
